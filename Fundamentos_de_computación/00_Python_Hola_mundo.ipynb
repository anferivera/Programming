# %% [markdown]
# Mi primer programa en python usando el Colab de Google

# %%
print('Hola mundo!')
# Out:
# Hola mundo!

# %%
print('hola')
# Out:
# hola

# %%
print("Hola")
# Out:
# Hola

# %%
print('hola')
# Out:
# hola
