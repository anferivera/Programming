# %% [markdown]
# <p><img alt="Colaboratory logo" height="140px" src="https://upload.wikimedia.org/wikipedia/commons/c/c3/Python-logo-notext.svg" align="left" hspace="10px" vspace="0px"></p>
#
# <h1> Python</h1>
#
# www.python.org - www.python.org
#
# <h1> Fundamentos en Computación</h1>
#
# Profs: Andrés F. Rivera R.
#
# *Cortecia: Nathaly Roa - GG*

# %% [markdown]
# www.python.org - www.python.org

# %% [markdown]
# <img src="https://www.python.org/static/community_logos/python-logo-master-v3-TM.png">
#
# Python es un **lenguaje interpretado** (en este curso seguiremos la versión de **Python 3.x**).
# Que sea interpretado significa que requiere de un programa que lea cada línea y ejecute la acción. Este proceso lo hace hasta que encuentre algún error, momento en el cual se detiene la ejecución del código.
# Python utiliza una serie de palabras claves que permiten establecer con claridad que es lo que se quiere hacer, por lo tanto no se pueden usar estas palabras como variables u otro tipo de objeto. Algunas son:
#
# <table>
# <tr>
# <td><b>print</b></td> <td><b>input</b></td> <td><b>plot</b></td> <td><b>in</b></td> <td><b>as</b></td> <td><b>True</b></td>
# </tr>
# <tr>
# <td><b>for</b></td> <td><b>while</b></td> <td><b>import</b></td> <td><b>def</b></td> <td><b>break</b></td> <td><b>False</b></td>
# </tr>
# <tr>
# <td><b>from</b></td> <td><b>int</b></td> <td><b>float</b></td> <td><b>str</b></td> <td><b>array</b></td> <td><b>list</b></td>
# </tr>
# </table>

# %% [markdown]
# # Entrada por teclado e impresión en pantalla en Python
#
#
# *   **Cadena de caracteres:** Permite representar una palabra o cualquier texto (`str`). Para escribir el texto se requiere encerrarlo en comillas simples **'** o dobles **"**:
#
# *Ejemplos:*

# %%
'Hola mundo'
# Out:
# 'Hola mundo'

# %%
type('Hola mundo')
# Out:
# str

# %%
print('Hola mundo')
# Out:
# Hola mundo

# %%
#Entada de datos por teclado
Nombres = input('Ingrese su nombre:')
Primer_apellido = input('Ingrese su primer apellido:')
Segundo_apellido = input('Ingrese su segundo apellido:')

#Imprimir datos en pantalla:
print('*****************************')
print(Nombres)
print(Primer_apellido)
print(Segundo_apellido)
# Out:
# Ingrese su nombre:Andres Felipe
# Ingrese su primer apellido:Rivera
# Ingrese su segundo apellido:Romero
# *****************************
# Andres Felipe
# Rivera
# Romero

# %%
print(Nombres)
# Out:
# Andres Felipe

# %%
print(Nombres + ' ' + Primer_apellido)
# Out:
# Andres Felipe Rivera

# %%
type(5)
# Out:
# int

# %%
Nombre_completo = Nombres + Primer_apellido + Segundo_apellido
print(Nombre_completo)
# Out:
# AnFeRi

# %% [markdown]
# Obsevación: $\color{red}{\text{los datos que se desean concatenar deben ser tipo string}}$ loc ual veremos en el sigueinte Notebook.
