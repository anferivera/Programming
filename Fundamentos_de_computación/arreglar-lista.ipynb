# %%
Ejercicio:
# Out:
#   File "<ipython-input-1-10a16db999a1>", line 1
#     Ejercicio:
#               ^
# SyntaxError: invalid syntax

# %%
import numpy as np

# %%
x = [1,0,3,8,10,20,4]

# %%
x
# Out:
# [1, 0, 3, 8, 10, 20, 4]

# %%
np.sort(x)
# Out:
# array([ 0,  1,  3,  4,  8, 10, 20])

# %%
np.random.randint(1,10)
# Out:
# 8

# %%
crear lista con numeros aleatorios

# %% [markdown]
# crear lista con numeros aleatorios

# %%
x = np.random.randint(1,100,10)

# %%
x
# Out:
# array([58, 91, 10, 32, 73, 53, 85, 45, 45, 38])

# %%
type(x)
# Out:
# numpy.ndarray

# %%
np.sort(x)
# Out:
# array([10, 32, 38, 45, 45, 53, 58, 73, 85, 91])

# %%
y = []

for i in range(0,10):
  z = np.random.randint(1,10)
  #print(i,z)
  y.append(z)

print(y)
# Out:
# [9, 7, 9, 2, 4, 3, 1, 7, 7, 6]
