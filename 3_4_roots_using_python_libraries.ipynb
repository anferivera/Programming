# %% [markdown]
# <a href="https://colab.research.google.com/github/anferivera/Metodos_Computacionales/blob/main/3_4_roots_using_python_libraries.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Root methods with tolerance

# %%
import numpy as np
import matplotlib.pyplot as plt

from matplotlib import animation
from scipy import integrate
from scipy import optimize

# %%
### ALL THE METHODS worked in classes

#++++++++++++++++++++++++++++++++++++++
#   Bisection Method: Simplest form
#++++++++++++++++++++++++++++++++++++++
def Bisection( f, a, b, Nmax=100, printer=False ):
    #verifying the STEP1, a and b with different signs
    if f(a)*f(b)>0:
        print("Error, f(a) and f(b) should have opposite signs")
        return False
    #Assigning the current extreme values, STEP2
    ai = a
    bi = b
    #Iterations
    n = 1
    while n<=Nmax:
        #Bisection, STEP3
        pi = (ai+bi)/2.0
        #Evaluating function in pi, STEP4 and STEP5
        if printer:
            print("Value for %d iterations:"%n,pi)
        #Condition A
        if f(pi)*f(ai)>0:
            ai = pi
        #Condition B
        elif f(pi)*f(ai)<0:
            bi = pi
        #Condition C: repeat the cycle
        n+=1
    #Final result
    return pi

#++++++++++++++++++++++++++++++++++++++
#   Fixed Point Method: Simplest form
#++++++++++++++++++++++++++++++++++++++
def FixedPoint( f, pini, Nmax=100):
    g = lambda x: x-f(x)
    #Iterations
    for n in range(Nmax):
        pini = g(pini)
    return pini

#++++++++++++++++++++++++++++++++++++++
#   Newton Method: Simplest form
#++++++++++++++++++++++++++++++++++++++
def NewtonRaphson( f, fp, pini, Nmax=100 ):
    #Initial condition
    p = pini
    #Iterations
    for n in range(Nmax):
        p = p - f(p)/fp(p)
    return p

#++++++++++++++++++++++++++++++++++++++
#   Secant Method: Simplest form
#++++++++++++++++++++++++++++++++++++++
def Secant_method( f, pini1, pini2, Nmax=100):
    #Initial condition
    pn1 = pini1
    pn2 = pini2
    #Iterations.
    for n in range(Nmax):
        if f(pn1)-f(pn2) == 0:
          break
        p = pn1 - f(pn1)*(pn1-pn2)/(f(pn1)-f(pn2))

        pn2 = pn1
        pn1 = p

    return p

# %% [markdown]
# # Example: Compute the root of $f(x)$

# %%
def f(x):
    return x**2-1

def df(x):
  return 2*x

# %%
def f(x):
    return x**3-2*x+2

def df(x):
  return 3*x**2-2

# %%
def f(x):
    return x - np.cos(x)

def df(x):
  return 1 + np.sin(x)

# %%
plt.figure(figsize=(5,4))
x = np.linspace(-2,2,100)
plt.plot(Bisection(f,-2,1),0,'ro',label='root')
plt.plot(x,f(x),label=r'$fx)$')
plt.hlines(0,-2,np.pi,'k')
#plt.vlines(0,np.min(f(x)),np.max(f(x)),'k')
plt.xlabel('x')
plt.ylabel('f(x)')

plt.legend(loc='best')
#plt.grid()
plt.show()

# %% [markdown]
# ## Example: using our differentes implementations

# %%
print('************ USING our methods *******************\n')
print('Bisection:    ', Bisection(f,0,1.5,20),'\n')
print('Fixed point:  ', FixedPoint(f,0.1,20),'\n')
print('NewtonRpahson:', NewtonRaphson(f,df,0.5,5),'\n')
print('Secant:       ', Secant_method(f,1.5,1.2,7),'\n')
print('*************************************************')
# Out:
# ************ USING our methods *******************
#
# Bisection:     0.7390837669372559
#
# Fixed point:   0.7389404933450101
#
# NewtonRpahson: 0.7390851332151607
#
# Secant:        0.7390851332151607
#
# *************************************************

# %% [markdown]
# ## Example: using scipy and python
#
# Let's compute the root for $f(x)$ using `scipy` library and check with:
# * **optimize.bisec** :
# * **optimize.fixed_point** :
# * **optimize.newton** : Find a root of the scalar-valued function func given a nearby scalar starting point x0. The Newton-Raphson method is used if the derivative fprime of func is provided, otherwise the **secant** method is used.

# %%
optimize.fixed_point(f,0.76)
# Out:
# array(-39.26990817)

# %%
import scipy.optimize as optimize

print('************ USING csipy *************************\n')
print("Using bisect SciPy:",         optimize.bisect(f, 0, 2, xtol=1e-17),'\n')
print("Using fixed_point SciPy:",    optimize.fixed_point(f,[0.5,0.99],  xtol=1e-6),'\n')
print("Using Newton-Raphson SciPy:", optimize.newton(f,0.5,fprime=df, tol=1e-06),'\n')
print("Using Secant SciPy:", optimize.newton(f,0.5,fprime=None, tol=1e-06),'\n')
print('**************************************************')
# Out:
# ************ USING csipy *************************
#
# Using bisect SciPy: 0.7390851332151605
#
# Using fixed_point SciPy: [29.84513021  1.57079633]
#
# Using Newton-Raphson SciPy: 0.7390851332151607
#
# Using Secant SciPy: 0.7390851332151601
#
# **************************************************

# %% [markdown]
# ## Methods with tolerance: BEST OF THE BEST!

# %%
### ALL THE METHODS with TOLERANCE tol

#++++++++++++++++++++++++++++++++++++++
#   Bisection: Simplest form with tol
#++++++++++++++++++++++++++++++++++++++
def Bisection_tol( f, a, b, tol=1e-6, Nmax=1000):
    'My Bisection method: run with tol=1e-6 by default. Return [root,n_iter]'
    #verifying a and b with different signs
    if f(a)*f(b)>0:
        print("Error, f(a) and f(b) should have opposite signs")
        return False
    #Assigning the current extreme values, STEP2
    ai = a
    bi = b
    #Iterations
    n = 1
    pi = (ai+bi)/2.0 #initial guess
    while np.abs(f(pi))>tol:
      pi = (ai+bi)/2.0 #Bisection: medium point
      #Condition A
      if f(pi)*f(ai)>0:
          ai = pi
      #Condition B
      elif f(pi)*f(ai)<0:
          bi = pi
      n+=1
      if n>Nmax:
        break

    return pi,n

#++++++++++++++++++++++++++++++++++++++
#   Fixed Point Method: Simplest form with tol
#++++++++++++++++++++++++++++++++++++++
def FixedPoint_tol( f, pini, tol=1e-6, Nmax=1000):
    'My Fixed point method: run with tol=1e-2 by default. Return [root,n_iter]'
    g = lambda x: x-f(x)
    #Iterations
    n=1
    while abs(f(pini))>tol:
        pini = g(pini)
        n +=1
        if n>Nmax:
          break
    return pini,n

#++++++++++++++++++++++++++++++++++++++
#   Newton Method: Simplest form with tol
#++++++++++++++++++++++++++++++++++++++
def NewtonRaphson_tol( f, fp, pini, tol=1e-10, Nmax=1000 ):
    'My Newton-Raphson method: run with tol=1e-6 by default. Return [root,n_iter]'
    p = pini #Initial condition
    #Iterations
    n = 1
    while abs(f(p))>tol:
      p = p - f(p)/fp(p)
      n +=1
      if n>Nmax:
        break
    return p,n

#++++++++++++++++++++++++++++++++++++++
#   Secant Method: Simplest form with tol
#++++++++++++++++++++++++++++++++++++++
def Secant_method_tol( f, pini1, pini2, tol=1e-14, Nmax=1000 ):
    'My Secant method: run with tol=1e-6 by default. Return [root,n_iter]'
    #Initial condition
    pn1 = pini1
    pn2 = pini2
    p = pn1
    n=1
    #Iterations.
    while abs(f(p))>tol:
      p = pn1 - f(pn1)*(pn1-pn2)/(f(pn1)-f(pn2))
      pn2 = pn1
      pn1 = p
      n +=1
      if n>Nmax:
        break
    return p,n

# %%
print('************ USING our methods *******************\n')
print('Bisection:    ', Bisection_tol(f,0.1,1.5),'\n')
print('NewtonRpahson:', NewtonRaphson_tol(f,df,0.5),'\n')
print('Secant:       ', Secant_method_tol(f,0.1,2.9),'\n')
print('Fixed point:  ', FixedPoint_tol(f,0.1),'\n')
print('*************************************************')
# Out:
# ************ USING our methods *******************
#
# Bisection:     (0.7390853881835939, 18)
#
# NewtonRpahson: (np.float64(0.7390851332151607), 5)
#
# Secant:        (np.float64(0.7390851332151603), 7)
#
# Fixed point:   (np.float64(0.7390845604122926), 35)
#
# *************************************************

# %% [markdown]
# Note: The fixed point works ugly!

# %% [markdown]
# # Newton method with and without tol...
#
# $P_{n+1}=P_n - \dfrac{f(p_n}{df(p_n)}$
#
# in next example, we see that Newton without tolerancia run the N times that we choose arbitrary. However, the rutine with tolerancia runs at to it gets the tolerance value and show the N that its need to get it.

# %%
def f(x):
    return x**3-2*x+2

def df(x):
  return 3*x**2-2

# %%
## Run N veces without tolerance
N = 30
for i in range(1,N):
  print('N=',i,NewtonRaphson(f,df,0.5,i))
# Out:
# N= 1 1.4
# N= 2 0.8989690721649484
# N= 3 -1.2887793276654596
# N= 4 -2.105767299013565
# N= 5 -1.8291999504602496
# N= 6 -1.771715812062107
# N= 7 -1.76929656115579
# N= 8 -1.769292354251341
# N= 9 -1.7692923542386314
# N= 10 -1.7692923542386314
# N= 11 -1.7692923542386314
# N= 12 -1.7692923542386314
# N= 13 -1.7692923542386314
# N= 14 -1.7692923542386314
# N= 15 -1.7692923542386314
# N= 16 -1.7692923542386314
# N= 17 -1.7692923542386314
# N= 18 -1.7692923542386314
# N= 19 -1.7692923542386314
# N= 20 -1.7692923542386314
# N= 21 -1.7692923542386314
# N= 22 -1.7692923542386314
# N= 23 -1.7692923542386314
# N= 24 -1.7692923542386314
# N= 25 -1.7692923542386314
# N= 26 -1.7692923542386314
# N= 27 -1.7692923542386314
# N= 28 -1.7692923542386314
# N= 29 -1.7692923542386314

# %%
# with tolerance
print('root:',NewtonRaphson_tol(f,df,0.5,tol=1E-16, Nmax=N)[0])
print('N:',NewtonRaphson_tol(f,df,0.5,tol=1E-16, Nmax=N)[1])
# Out:
# root: -1.7692923542386314
# N: 10

# %% [markdown]
# $$\text{The end!}$$
